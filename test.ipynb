# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('image.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print("image is", image.shape, "of type", image[0][0][0].dtype)
print("gray is", gray.shape, "of type", gray[0][0].dtype)
plt.imshow(gray, cmap='gray')
plt.show()
# Out:
# image is (500, 752, 3) of type uint8
# gray is (500, 752) of type uint8

# %%
# Find the chessboard corners
ret, corners = cv2.findChessboardCorners(gray, (6, 6), None)

# If found, draw corners
if ret == True:
    # Draw and display the corners
    cv2.drawChessboardCorners(image, (6, 6), corners, ret)
    plt.imshow(image)
    plt.show()
else:
    print('Chessboard corners not found')
